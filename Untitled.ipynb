# %%
import pandas as pd
import os

# %%
df = pd.read_csv('ml-25m/ratings.csv')

# %%
df.describe()
# Out:
#              userId       movieId        rating     timestamp
# count  2.500010e+07  2.500010e+07  2.500010e+07  2.500010e+07
# mean   8.118928e+04  2.138798e+04  3.533854e+00  1.215601e+09
# std    4.679172e+04  3.919886e+04  1.060744e+00  2.268758e+08
# min    1.000000e+00  1.000000e+00  5.000000e-01  7.896520e+08
# 25%    4.051000e+04  1.196000e+03  3.000000e+00  1.011747e+09
# 50%    8.091400e+04  2.947000e+03  3.500000e+00  1.198868e+09
# 75%    1.215570e+05  8.623000e+03  4.000000e+00  1.447205e+09
# max    1.625410e+05  2.091710e+05  5.000000e+00  1.574328e+09

# %%
df.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1      296     5.0  1147880044
# 1       1      306     3.5  1147868817
# 2       1      307     5.0  1147868828
# 3       1      665     5.0  1147878820
# 4       1      899     3.5  1147868510

# %%
personality = pd.read_csv('personality-isf2018/personality-data.csv')

# %%
personality.head()
# Out:
#                              userid   openness   agreeableness  \
# 0  8e7cebf9a234c064b75016249f2ac65e        5.0             2.0
# 1  77c7d756a093150d4377720abeaeef76        7.0             4.0
# 2  b7e8a92987a530cc368719a0e60e26a3        4.0             3.0
# 3  92561f21446e017dd6b68b94b23ad5b7        5.5             5.5
# 4  030001ac2145a938b07e686a35a2d638        5.5             5.5
#
#     emotional_stability   conscientiousness   extraversion  assigned metric  \
# 0                   3.0                 2.5            6.5      serendipity
# 1                   6.0                 5.5            4.0              all
# 2                   4.5                 2.0            2.5      serendipity
# 3                   4.0                 4.5            4.0       popularity
# 4                   3.5                 4.5            2.5       popularity
#
#    assigned condition   movie_1   predicted_rating_1  ...   movie_9  \
# ...

# %%
ratings = pd.read_csv('personality-isf2018/ratings.csv')

# %%
ratings.head()
# Out:
#                               useri   movie_id   rating                tstamp
# 0  8e7cebf9a234c064b75016249f2ac65e          1      5.0   2001-09-10 17:19:56
# 1  8e7cebf9a234c064b75016249f2ac65e          2      4.0   2001-09-28 11:34:55
# 2  8e7cebf9a234c064b75016249f2ac65e          3      4.0   2001-09-28 11:42:50
# 3  8e7cebf9a234c064b75016249f2ac65e          5      5.0   2001-09-28 11:27:30
# 4  8e7cebf9a234c064b75016249f2ac65e          6      4.0   2002-01-07 18:12:02

# %%
ratings.describe()
# Out:
#            movie_id        rating
# count  1.028751e+06  1.028751e+06
# mean   4.083825e+04  3.370212e+00
# std    4.844535e+04  1.010081e+00
# min    1.000000e+00  5.000000e-01
# 25%    2.628000e+03  3.000000e+00
# 50%    7.361000e+03  3.500000e+00
# 75%    7.475400e+04  4.000000e+00
# max    1.981170e+05  5.000000e+00

# %%
base = './ml-25m/'

for f in os.listdir('./ml-25m'):
    if (f.endswith('.csv')):
        print(f)
        print(pd.read_csv(base + f))
# Out:
# tags.csv
#          userId  movieId                  tag   timestamp
# 0             3      260              classic  1439472355
# 1             3      260               sci-fi  1439472256
# 2             4     1732          dark comedy  1573943598
# 3             4     1732       great dialogue  1573943604
# 4             4     7569     so bad it's good  1573943455
# ...         ...      ...                  ...         ...
# 1093355  162521    66934  Neil Patrick Harris  1427311611
# 1093356  162521   103341     cornetto trilogy  1427311259
# 1093357  162534   189169               comedy  1527518175
# 1093358  162534   189169             disabled  1527518181
# 1093359  162534   189169              robbery  1527518193
#
# [1093360 rows x 4 columns]
# ratings.csv
#           userId  movieId  rating   timestamp
# 0              1      296     5.0  1147880044
# 1              1      306     3.5  1147868817
# 2              1      307     5.0  1147868828
# ...

# %%
files = {filename.split('.')[0]:"./ml-25m/{}".format(filename) for filename in os.listdir('./ml-25m') if filename.endswith('csv')}
files
# Out:
# {'tags': './ml-25m/tags.csv',
#  'ratings': './ml-25m/ratings.csv',
#  'genome-scores': './ml-25m/genome-scores.csv',
#  'movies': './ml-25m/movies.csv',
#  'links': './ml-25m/links.csv',
#  'genome-tags': './ml-25m/genome-tags.csv'}

# %%
tags_df = pd.read_csv(files['genome-tags'])

# %%
gs_df = pd.read_csv(files['genome-scores'])

# %%
gs_df.head()
# Out:
#    movieId  tagId  relevance
# 0        1      1    0.02875
# 1        1      2    0.02375
# 2        1      3    0.06250
# 3        1      4    0.07575
# 4        1      5    0.14075

# %%
toy_story_tags = gs_df[gs_df.movieId == 1]

# %%
t10_toy_story = toy_story_tags.sort_values('relevance', ascending=False)[0:50]
t10_toy_story
# Out:
#       movieId  tagId  relevance
# 1035        1   1036    0.99925
# 243         1    244    0.99875
# 785         1    786    0.99575
# 588         1    589    0.98575
# 63          1     64    0.98425
# 587         1    588    0.98000
# 784         1    785    0.96450
# 203         1    204    0.95975
# 185         1    186    0.95475
# 62          1     63    0.94725
# 535         1    536    0.93675
# 411         1    412    0.92875
# 970         1    971    0.91625
# 468         1    469    0.90725
# 202         1    203    0.90375
# 1061        1   1062    0.89625
# 28          1     29    0.89375
# 309         1    310    0.89300
# 741         1    742    0.88575
# 413         1    414    0.87625
# 602         1    603    0.87475
# 716         1    717    0.87225
# 444         1    445    0.86825
# 277         1    278    0.84200
# 308         1    309    0.83925
# 373         1    374    0.83150
# 214         1    215    0.81500
# 192         1    193    0.81450
# ...

# %%
t10_toy_story.set_index('tagId')
# Out:
#        movieId  relevance
# tagId
# 1036         1    0.99925
# 244          1    0.99875
# 786          1    0.99575
# 589          1    0.98575
# 64           1    0.98425
# 588          1    0.98000
# 785          1    0.96450
# 204          1    0.95975
# 186          1    0.95475
# 63           1    0.94725
# 536          1    0.93675
# 412          1    0.92875
# 971          1    0.91625
# 469          1    0.90725
# 203          1    0.90375
# 1062         1    0.89625
# 29           1    0.89375
# 310          1    0.89300
# 742          1    0.88575
# 414          1    0.87625
# 603          1    0.87475
# 717          1    0.87225
# 445          1    0.86825
# 278          1    0.84200
# 309          1    0.83925
# 374          1    0.83150
# 215          1    0.81500
# 193          1    0.81450
# 497          1    0.81225
# 464          1    0.80950
# 415          1    0.79900
# 748          1    0.77950
# 761          1    0.77050
# 743          1    0.76550
# ...

# %%
t10_ts = t10_toy_story.join(tags_df, lsuffix='_caller', rsuffix='_other')
t10_ts
# Out:
#       movieId  tagId_caller  relevance  tagId_other  \
# 1035        1          1036    0.99925         1036
# 243         1           244    0.99875          244
# 785         1           786    0.99575          786
# 588         1           589    0.98575          589
# 63          1            64    0.98425           64
# 587         1           588    0.98000          588
# 784         1           785    0.96450          785
# 203         1           204    0.95975          204
# 185         1           186    0.95475          186
# 62          1            63    0.94725           63
# 535         1           536    0.93675          536
# 411         1           412    0.92875          412
# 970         1           971    0.91625          971
# 468         1           469    0.90725          469
# 202         1           203    0.90375          203
# 1061        1          1062    0.89625         1062
# 28          1            29    0.89375           29
# ...

# %%
t10_ts['tag']
# Out:
# 1035                  toys
# 243     computer animation
# 785        pixar animation
# 588        kids and family
# 63               animation
# 587                   kids
# 784                  pixar
# 203               children
# 185                cartoon
# 62                animated
# Name: tag, dtype: object

# %%
ratings[ratings.movieId == 1]
# Out:
#           userId  movieId  rating   timestamp
# 70             2        1     3.5  1141415820
# 254            3        1     4.0  1439472215
# 910            4        1     3.0  1573944252
# 1152           5        1     4.0   858625949
# 1304           8        1     4.0   890492517
# ...          ...      ...     ...         ...
# 24997918  162529        1     2.0   888181499
# 24998300  162530        1     5.0   989808332
# 24998525  162533        1     4.5  1280920369
# 24998892  162534        1     4.0  1526714137
# 24999624  162538        1     2.0  1438780765
#
# [57309 rows x 4 columns]

# %%
vuosittaiset genre genomisuosikit / tagit / etc...
